# %%
import pandas as pd
import json

# %%
# Import the count table
count_table = pd.read_csv("/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/feature-table.tsv", sep="\t", header=0, index_col=0)
count_table
# Out:
#                                                     K_negativo_PCR_SU014_S14  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                            1.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                            3.0
# S004584625                                                               2.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                       0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                       0.0
# ...                                                                      ...
# S003739388                                                               0.0
# S000346258                                                               0.0
# S004233564                                                               0.0
# S002103814                                                               0.0
# S000544145                                                               0.0
#
#                                                     RE-51_23_EX24_2-69_SU002_LJ_S2  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                 0.00
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                 0.00
# S004584625                                                                    0.00
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                        16652.55
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                            3.33
# ...                                                                            ...
# S003739388                                                                    0.00
# S000346258                                                                    0.00
# S004233564                                                                    0.00
# S002103814                                                                    0.00
# S000544145                                                                    0.00
#
#                                                     RE-36_23_EX24_2-57_SU001_LJ_S1  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S004584625                                                                     0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# ...                                                                            ...
# S003739388                                                                     0.0
# S000346258                                                                     0.0
# S004233564                                                                     0.0
# S002103814                                                                     0.0
# S000544145                                                                     0.0
#
#                                                     CO-VE-21_09_EX24_2-105_SU006_LJ_S6  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                      0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                      0.0
# S004584625                                                                         0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                                 0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                                 0.0
# ...                                                                                ...
# S003739388                                                                         0.0
# S000346258                                                                         0.0
# S004233564                                                                         0.0
# S002103814                                                                         0.0
# S000544145                                                                         0.0
#
#                                                     CO-15_22_EX24_2-82_SU005_LJ_S5  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S004584625                                                                     0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# ...                                                                            ...
# S003739388                                                                     0.0
# S000346258                                                                     0.0
# S004233564                                                                     0.0
# S002103814                                                                     0.0
# S000544145                                                                     0.0
#
#                                                     K_negativo_orina_EX24_2-85_SU007_LJ_S7  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                          0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                          0.0
# S004584625                                                                             0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                                     0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                                     0.0
# ...                                                                                    ...
# S003739388                                                                             0.0
# S000346258                                                                             0.0
# S004233564                                                                             0.0
# S002103814                                                                             0.0
# S000544145                                                                             0.0
#
#                                                     K_positivo_PCR_MOCK_SU008_S8  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                0.0
# S004584625                                                                   0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                           0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                           0.0
# ...                                                                          ...
# S003739388                                                                   0.0
# S000346258                                                                   0.0
# S004233564                                                                   0.0
# S002103814                                                                   0.0
# S000544145                                                                   0.0
#
#                                                     CO-09_22_EX24_2-78_SU004_LJ_S4  \
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S004584625                                                                     0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# ...                                                                            ...
# S003739388                                                                     0.0
# S000346258                                                                     0.0
# S004233564                                                                     0.0
# S002103814                                                                     0.0
# S000544145                                                                     0.0
#
#                                                     RE-54_23_EX24_2-72_SU003_LJ_S3
# S003617148;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S000826305;sample_id=K_negativo_PCR_SU014_S14                                  0.0
# S004584625                                                                     0.0
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...                             0.0
# ...                                                                            ...
# S003739388                                                                     1.0
# S000346258                                                                     1.0
# S004233564                                                                     1.0
# S002103814                                                                     1.0
# S000544145                                                                     1.0
#
# [1408 rows x 9 columns]

# %%
# Import the taxonomy table
taxonomy_table = pd.read_csv(
    "/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/taxonomy-table.tsv",
    sep="\t",
    header=0,
    index_col=0
    )
taxonomy_table
# Out:
#                                                                                               lineage
# feature
# S003617148;sample_id=K_negativo_PCR_SU014_S14       r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# S000826305;sample_id=K_negativo_PCR_SU014_S14       r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# S004584625                                          r__Root;d__Bacteria;p__Proteobacteria;c__Gamma...
# S000826419;sample_id=RE-51_23_EX24_2-69_SU002_L...  r__Root;d__Bacteria;p__Firmicutes;c__Bacilli;o...
# S000536413;sample_id=RE-51_23_EX24_2-69_SU002_L...  r__Root;d__Bacteria;p__Firmicutes;c__Negativic...
# ...                                                                                               ...
# S003739388                                          r__Root;d__Bacteria;p__Proteobacteria;c__Alpha...
# S000346258                                          r__Root;d__Bacteria;p__Firmicutes;c__Bacilli;o...
# S004233564                                          r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# S002103814                                          r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# S000544145                                          r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
#
# [1408 rows x 1 columns]

# %%
def create_index_dict(df):
    """
    Creates a dictionary mapping old index values to new index values of a pandas DataFrame.
    

    The new index values are generated as "seq_" followed by a zero-padded
    integer corresponding to the row position (1-indexed).

    Parameters
    ----------
        df (pandas.DataFrame): Input DataFrame.

    Returns
    -------
        dict: Dictionary mapping old index values to new index values.

    Example:
        >>> df = pd.DataFrame({'A': [1, 2, 3]})
        >>> index_map = create_index_dict(df)
        >>> print(index_map)
        {0: 'seq_001', 1: 'seq_002', 2: 'seq_003'}
    """

    import pandas as pd
    
    max_rows = len(df)
    max_digits = len(str(max_rows))
    old_to_new_index_map = {}
    for i, old_index in enumerate(df.index):
        new_index = f"seq_{str(i+1).zfill(max_digits)}"
        old_to_new_index_map[old_index] = new_index
    return old_to_new_index_map

# %%
# Map new and old index values
id_map = create_index_dict(count_table)

# %%
# Rename the index of the count table
count_table = count_table.rename(index=id_map)
count_table
# Out:
#           K_negativo_PCR_SU014_S14  RE-51_23_EX24_2-69_SU002_LJ_S2  \
# seq_0001                       1.0                            0.00
# seq_0002                       3.0                            0.00
# seq_0003                       2.0                            0.00
# seq_0004                       0.0                        16652.55
# seq_0005                       0.0                            3.33
# ...                            ...                             ...
# seq_1404                       0.0                            0.00
# seq_1405                       0.0                            0.00
# seq_1406                       0.0                            0.00
# seq_1407                       0.0                            0.00
# seq_1408                       0.0                            0.00
#
#           RE-36_23_EX24_2-57_SU001_LJ_S1  CO-VE-21_09_EX24_2-105_SU006_LJ_S6  \
# seq_0001                             0.0                                 0.0
# seq_0002                             0.0                                 0.0
# seq_0003                             0.0                                 0.0
# seq_0004                             0.0                                 0.0
# seq_0005                             0.0                                 0.0
# ...                                  ...                                 ...
# seq_1404                             0.0                                 0.0
# seq_1405                             0.0                                 0.0
# seq_1406                             0.0                                 0.0
# seq_1407                             0.0                                 0.0
# seq_1408                             0.0                                 0.0
#
#           CO-15_22_EX24_2-82_SU005_LJ_S5  \
# seq_0001                             0.0
# seq_0002                             0.0
# seq_0003                             0.0
# seq_0004                             0.0
# seq_0005                             0.0
# ...                                  ...
# seq_1404                             0.0
# seq_1405                             0.0
# seq_1406                             0.0
# seq_1407                             0.0
# seq_1408                             0.0
#
#           K_negativo_orina_EX24_2-85_SU007_LJ_S7  \
# seq_0001                                     0.0
# seq_0002                                     0.0
# seq_0003                                     0.0
# seq_0004                                     0.0
# seq_0005                                     0.0
# ...                                          ...
# seq_1404                                     0.0
# seq_1405                                     0.0
# seq_1406                                     0.0
# seq_1407                                     0.0
# seq_1408                                     0.0
#
#           K_positivo_PCR_MOCK_SU008_S8  CO-09_22_EX24_2-78_SU004_LJ_S4  \
# seq_0001                           0.0                             0.0
# seq_0002                           0.0                             0.0
# seq_0003                           0.0                             0.0
# seq_0004                           0.0                             0.0
# seq_0005                           0.0                             0.0
# ...                                ...                             ...
# seq_1404                           0.0                             0.0
# seq_1405                           0.0                             0.0
# seq_1406                           0.0                             0.0
# seq_1407                           0.0                             0.0
# seq_1408                           0.0                             0.0
#
#           RE-54_23_EX24_2-72_SU003_LJ_S3
# seq_0001                             0.0
# seq_0002                             0.0
# seq_0003                             0.0
# seq_0004                             0.0
# seq_0005                             0.0
# ...                                  ...
# seq_1404                             1.0
# seq_1405                             1.0
# seq_1406                             1.0
# seq_1407                             1.0
# seq_1408                             1.0
#
# [1408 rows x 9 columns]

# %%
# Rename the index of the taxonomy table
taxonomy_table = taxonomy_table.rename(index=id_map)
taxonomy_table
# Out:
#                                                     lineage
# feature
# seq_0001  r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# seq_0002  r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# seq_0003  r__Root;d__Bacteria;p__Proteobacteria;c__Gamma...
# seq_0004  r__Root;d__Bacteria;p__Firmicutes;c__Bacilli;o...
# seq_0005  r__Root;d__Bacteria;p__Firmicutes;c__Negativic...
# ...                                                     ...
# seq_1404  r__Root;d__Bacteria;p__Proteobacteria;c__Alpha...
# seq_1405  r__Root;d__Bacteria;p__Firmicutes;c__Bacilli;o...
# seq_1406  r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# seq_1407  r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
# seq_1408  r__Root;d__Bacteria;p__Actinobacteria;c__Actin...
#
# [1408 rows x 1 columns]

# %%
# Format the taxonomy string in the taxonomy table
taxonomy_table["lineage"] = taxonomy_table["lineage"].str.replace("\\w__", "", regex=True)
taxonomy_table = taxonomy_table["lineage"].str.split(";", expand=True)
taxonomy_table.columns = ["Root", "Kingdom", "Phylum", "Class", "Order", "Family", "Genus", "Species"]
taxonomy_table
# Out:
#           Root   Kingdom          Phylum                Class  \
# feature
# seq_0001  Root  Bacteria  Actinobacteria       Actinobacteria
# seq_0002  Root  Bacteria  Actinobacteria       Actinobacteria
# seq_0003  Root  Bacteria  Proteobacteria  Gammaproteobacteria
# seq_0004  Root  Bacteria      Firmicutes              Bacilli
# seq_0005  Root  Bacteria      Firmicutes        Negativicutes
# ...        ...       ...             ...                  ...
# seq_1404  Root  Bacteria  Proteobacteria  Alphaproteobacteria
# seq_1405  Root  Bacteria      Firmicutes              Bacilli
# seq_1406  Root  Bacteria  Actinobacteria       Actinobacteria
# seq_1407  Root  Bacteria  Actinobacteria       Actinobacteria
# seq_1408  Root  Bacteria  Actinobacteria       Actinobacteria
#
#                         Order                Family            Genus  \
# feature
# seq_0001        Micrococcales        Micrococcaceae          Kocuria
# seq_0002  Propionibacteriales  Propionibacteriaceae    Cutibacterium
# seq_0003      Pseudomonadales         Moraxellaceae    Acinetobacter
# seq_0004      Lactobacillales      Lactobacillaceae    Lactobacillus
# seq_0005       Veillonellales       Veillonellaceae        Dialister
# ...                       ...                   ...              ...
# seq_1404          Rhizobiales  Pleomorphomonadaceae  Pleomorphomonas
# seq_1405           Bacillales         Bacillaceae 1             None
# seq_1406        Micrococcales     Microbacteriaceae             None
# seq_1407      Mycobacteriales    Corynebacteriaceae  Corynebacterium
# seq_1408        Micrococcales    Intrasporangiaceae       Janibacter
#
#                               Species
# feature
# seq_0001              Kocuria varians
# seq_0002          Cutibacterium acnes
# seq_0003                         None
# seq_0004          Lactobacillus iners
# seq_0005  Dialister propionicifaciens
# ...                               ...
# seq_1404                         None
# seq_1405                         None
# seq_1406                         None
# seq_1407                         None
# seq_1408            Janibacter hoylei
#
# [1408 rows x 8 columns]

# %%
# Export the taxonomy table
taxonomy_table.to_csv(
    "/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/taxonomy_table_parsed.tsv",
    sep="\t",
    header=True,
    index=True,
)

# %%
# Export the count table
count_table.to_csv(
    "/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/count_table_parsed.tsv",
    sep="\t",
    header=True,
    index=True,
)

# %%
# Write the JSON string to a file
with open("/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/id_map.json", "w") as f:
    f.write(json.dumps(id_map))

# %%
def parse_fasta(fasta_in, fasta_out, id_map):
    """
    Parse a FASTA file, change its heeaders based on a dictionary 
    mapping old index values to new index values, 
    and sort the sequences alphabetically based on their headers.

    Parameters  
    ---------- 
        fasta_in (str): The path to the input FASTA file.
        fasta_out (str): The path to the output FASTA file.
        id_map (dict): A dictionary mapping old header to new headers.

    Returns
    -------
        None
    """

    with open(fasta_in, "r") as fasta:
        # The recurrent use of .strip() avoids trailing newlines and spaces problems.
        parsed_fasta = []
        for line in fasta:
            if line.startswith(">"):
                seq_id = line.replace(">", "").strip()
                parsed_fasta.append(id_map[seq_id])
            else:
                parsed_fasta.append(line.upper().strip()) # Make sure the sequence is uppercase

    def sort_fasta(fasta_list):
        """
        This is a helper function that sorts the fasta file based on the headers.

        Parameters
        ----------
        fasta_list : list
            A list of strings representing the fasta file.

        Returns
        -------
        sorted_fasta : Pandas DataFrame
            A pandas DataFrame mapping headers to sequences.
        """

        import pandas as pd

        sorted_fasta = pd.DataFrame.from_dict(dict(zip(fasta_list[::2], fasta_list[1::2])), "index")
        sorted_fasta.sort_index(inplace=True)

        return sorted_fasta

    # Sort the parsed fasta
    sorted_fasta = sort_fasta(parsed_fasta)

    # Transform to a dict and write the fasta file
    output = sorted_fasta.to_dict()[0]
    with open(fasta_out, "w") as f:
        for seq_id, seq in output.items():
            f.write(f">{seq_id}\n{seq}\n")

    # Return the sorted fasta DataFrame
    return sorted_fasta

# %%
def build_seq_table(fasta_df, id_map):
    """
    Constructs a sequence table from a DataFrame of FASTA sequences and an ID mapping.

    This function takes a DataFrame containing FASTA sequences and a dictionary
    mapping new sequence IDs to their original IDs. It creates a new DataFrame
    with two columns: 'Origin', which contains the original sequence IDs, and
    'Sequence', which contains the corresponding sequences.

    Parameters
    ----------
    fasta_df : pandas.DataFrame
        A DataFrame where each row represents a sequence with its ID as the index.
    id_map : dict
        A dictionary mapping new sequence IDs to original sequence IDs.

    Returns
    -------
    pandas.DataFrame
        A DataFrame with 'Origin' and 'Sequence' columns, mapping original IDs
        to their respective sequences.
    """

    import pandas as pd

    # Make a deep copy to avoid modifying the original DataFrame
    sequence_table = fasta_df.copy(deep=True)
    # Rename index column and sequence column
    sequence_table.index.names = ["ID"]
    sequence_table.columns = ["Sequence"]

    # Invert the id_mapping so it accepts the simplified ID as key
    inv_map = {v: k for k, v in id_map.items()}

    # Add the original ID to the sequence table
    sequence_table["Origin"] = [inv_map[header] for header in fasta_df.index]
    # Reorder the columns
    sequence_table = sequence_table[["Origin", "Sequence"]]

    return sequence_table

# %%
fasta_in = "/home/jose.gomez/Projects/16S_completo/test/orina/output/templates.fasta"
fasta_out = (
    "/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/templates_parsed.fasta"
)
outfile = "/home/jose.gomez/Projects/16S_completo/test/orina/RESDIR/sequence_table.tsv"

# %%
parsed_fasta_df = parse_fasta(fasta_in, fasta_out, id_map)
sequence_table = build_seq_table(parsed_fasta_df, id_map)
sequence_table.to_csv(outfile, sep="\t", header=True, index=True)
